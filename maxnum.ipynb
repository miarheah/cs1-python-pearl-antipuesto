# %% [markdown]
# <a href="https://colab.research.google.com/github/miarheah/cs1-python-pearl-antipuesto/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter your name: ")
# Out:
# Enter your name: Pearl

# %%
num1 = int(input("Enter 1st number: "))
# Out:
# Enter 1st number: 13

# %%
num2 = int(input("Enter 2nd number: "))
# Out:
# Enter 2nd number: 16

# %%
num3 = int(input("Enter 3rd number: "))
# Out:
# Enter 3rd number: 27

# %%
print("Hello, ", name)
# Out:
# Hello,  Pearl

# %%
#compare the numbers

# %%
if (num1 >= num2) and (num1 >= num3):
    print("The biggest number is", num1)
elif (num2 >= num1) and (num2 >= num3):
    print("The biggest number is", num2)
elif (num3 >= num1) and (num3 >= num2):
    print("The biggest number is", num3)
else:
    print(num1, num2, "and", num3, "are equal")
# Out:
# The biggest number is 27
